# %% [markdown]
# <a href="https://colab.research.google.com/github/Anand-24G/fmml2021/blob/main/M8-FMML_Course_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# <table class="tfo-notebook-buttons" align="left">
#   <td>
#     <a target="_blank" href="https://colab.research.google.com/drive/1TuDbIyso6irdyBFgaHRpC-PxUICWPHcS?usp=sharing"><img height="32px" src="https://colab.research.google.com/img/colab_favicon.ico" />Run in Google Colab</a>
#   </td>
#   <td>
#     <a target="_blank" href="https://github.com/Foundations-in-Modern-Machine-Learning/course-contents/tree/main/Bayesian/"><img src="https://www.tensorflow.org/images/GitHub-Mark-32px.png" />View source on GitHub</a>
#   </td>
# </table>
# <br>
# <br>
# <br>

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2022-06-15 15:28:52--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json.1’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   174MB/s    in 0.4s
#
# 2022-06-15 15:28:53 (174 MB/s) - ‘arxiv-paper-data.json.1’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False), 
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split() 
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 22725  1705.07178v2  Inference of latent feature models in the Baye...  stat
# 39904  1707.05411v2  This paper introduces and evaluates a hybrid t...    cs
# 38270  1508.00504v1  Using the SSWL database of syntactic parameter...    cs
# 1027   1602.08194v2  Current deep learning architectures are growin...  stat
# 39321  1510.03909v1  Automated recognition of facial expressions of...    cs
# ...             ...                                                ...   ...
# 5395    1107.2462v2  Machine learning approaches to multi-label doc...  stat
# 11811  1702.02267v4  We consider the problem of reconstructing a ra...  stat
# 11555  1606.00389v3  We propose a streaming submodular maximization...  stat
# 10568   1303.6370v1  We discuss structured Schatten norms for tenso...  stat
# 21981   1307.0293v3  The vector autoregressive (VAR) model is a pow...  stat
#
#                                                    title  year  \
# 22725   Accelerated Inference for Latent Variable Models  2017
# 39904  Hybrid PS-V Technique: A Novel Sensor Fusion A...  2017
# 38270  Spin Glass Models of Syntax and Language Evolu...  2015
# 1027   Scalable and Sustainable Deep Learning via Ran...  2016
# 39321  Variable-state Latent Conditional Random Field...  2015
# ...                                                  ...   ...
# 5395   Statistical Topic Models for Multi-Label Docum...  2011
# 11811  Matrix Completion from $O(n)$ Samples in Linea...  2017
# 11555  Stream Clipper: Scalable Submodular Maximizati...  2016
# 10568  Convex Tensor Decomposition via Structured Sch...  2013
# 21981  A Direct Estimation of High Dimensional Statio...  2013
#
#                                                 keywords
# 22725  [inference, nonparametric, generally, difficul...
# 39904  [introduces, evaluates, technique, efficiently...
# 38270  [syntactic, parameters, languages, interaction...
# 1027   [architectures, architectures, multiplication,...
# 39321  [automated, recognition, expressions, detectio...
# ...                                                  ...
# 5395   [approaches, classification, discriminative, t...
# 11811  [reconstructing, incoherence, assumption, cond...
# 11555  [streaming, submodular, maximization, algorith...
# 10568  [structured, decomposition, optimization, deco...
# 21981  [autoregressive, exploited, dimensional, chall...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 22725    [inference, nonparametric, generally, difficul...
# 39904    [introduces, evaluates, technique, efficiently...
# 38270    [syntactic, parameters, languages, interaction...
# 1027     [architectures, architectures, multiplication,...
# 39321    [automated, recognition, expressions, detectio...
#                                ...
# 3910     [clustering, functions, attracting, conflictin...
# 6668     [classification, challenging, dimensional, cor...
# 6722     [abstention, feedbacks, abstention, important,...
# 38960    [effective, representations, recognition, reco...
# 23616    [addresses, correlation, estimation, compresse...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]), 
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8783 words.
# Out of those 4586 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="eeaf80b0-f426-4448-a8da-f829bc91ae98" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("eeaf80b0-f426-4448-a8da-f829bc91ae98")) {                    Plotly.newPlot(                        "eeaf80b0-f426-4448-a8da-f829bc91ae98",                        [{"x":["integration","predictive","difficult","theoretically","performed","locations","distribution","generally","dimensions","computationally","especially","dimensional","nonparametric","posterior","accelerated","likelihood","inference","proposing","according","efficient","tractable","attractive","assignments","guaranteed","accelerate","mechanism","experimental","evaluates","evaluation","robustness","technique","combinations","efficiently","otherwise","potentially","developed","involving","principles","movements","horizontal","operating","performing","scenarios","functional","correction","components","introduces","generalization","construct","parameters","temperature","entailment","syntactic","modification","evolution","relations","different","languages","ferromagnetic","linguistic","simulations","interpretation","assumption","materials","interactions","interaction","naturally","operations","multiplication","randomized","scalability","activation","multiplications","conversely","asynchronous","associated","evaluations","sustainable","consequence","standpoint","algorithm","computational","significantly","increasing","sustainability","propagation","demonstrate","expensive","architectures","computation","drastically","containing","recognition","characterized","accounting","underlying","appearance","laplacian","relationships","regularization","overfitting","expressions","traditional","unordered","consistency","expression","conditional","restrictive","critically","discriminate","framework","activations","typically","intensity","databases","performance","described","challenging","experiments","automatically","structure","considerably","detection","automated","cognitive","improving","substantial","impairment","cognition","distinguish","minimizes","reinforcement","progression","approaches","prediction","supervised","participants","outperform","maximizes","differentiating","significant","conversational","conversation","probability","promising","transcripts","diagnosis","transcribed","simulation","alzheimers","specifically","observations","applications","residuals","covariate","heteroscedasticity","regression","dependent","synthetic","additional","derivative","covariance","frequently","heteroscedastic","unobserved","fundamental","population","conditions","following","algorithms","contemporary","estimated","prohibitively","computing","explicitly","sufficient","approximate","requirements","approximately","quadratic","furthermore","detecting","illustrate","alternative","execution","modularity","programming","drawbacks","conducted","advantages","impractical","difficulty","inherited","transition","definition","presenting","environments","generated","generation","conventional"],"y":[48,61,132,35,134,34,231,68,42,93,120,177,17,37,20,71,224,24,110,409,31,21,7,34,26,108,381,7,237,81,279,44,138,23,43,213,53,41,12,3,18,86,102,36,20,100,83,111,99,233,7,14,47,25,65,125,728,113,1,79,33,59,72,13,87,76,48,66,9,23,46,31,0,4,13,111,55,2,32,5,780,283,271,105,1,70,536,57,110,142,11,56,364,33,6,130,85,19,64,67,28,40,188,4,43,46,94,6,6,9,553,25,106,17,49,888,80,242,607,174,334,32,345,83,60,100,33,3,15,39,18,114,11,407,212,186,22,82,12,5,236,19,12,182,99,3,48,3,89,4,157,83,414,3,4,0,130,82,135,109,8,25,19,0,7,84,42,141,81,599,11,68,10,129,64,66,98,47,24,33,161,96,68,87,26,10,119,17,79,80,10,48,5,37,42,17,82,163,151,89],"type":"bar"},{"x":["integration","predictive","difficult","theoretically","performed","locations","distri ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4586,), (4586, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7958333333333333

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Text</span> <span style=''>To</span> <span style=''>Speech</span> <span style='background-color:rgba(0, 255, 0, 0.5294117647058825);'>Conversion</span> <span style=''>with</span> <span style=''>Neural</span> <span style=''>Networks</span> <span style=''>A</span> <span style='background-color:rgba(0, 255, 0, 0.431372549019608);'>Recurrent</span> <span style=''>TDNN</span> <span style=''>Approach</span> <br/><br/><span style=''>This</span> <span style=''>paper</span> <span style='background-color:rgba(0, 255, 0, 0.5409836065573772);'>describes</span> <span style=''>the</span> <span style=''>design</span> <span style=''>of</span> <span style=''>a</span> <span style=''>neural</span> <span style=''>network</span> <span style=''>that</span> <span style=''>performs</span> <span style=''>the</span> <span style=''>phonetic</span> <span style=''>to</span> <span style=''>acoustic</span> <span style=''>mapping</span> <span style=''>in</span> <span style=''>a</span> <span style=''>speech</span> <span style='background-color:rgba(0, 255, 0, 0.6271186440677967);'>synthesis</span> <span style=''>system</span> <span style=''>The</span> <span style=''>use</span> <span style=''>of</span> <span style=''>a</span> <span style=''>time</span> <span style=''>domain</span> <span style=''>neural</span> <span style=''>network</span> <span style='background-color:rgba(0, 255, 0, 0.5192307692307692);'>architecture</span> <span style=''>limits</span> <span style='background-color:rgba(0, 255, 0, 0.7142857142857143);'>discontinuities</span> <span style=''>that</span> <span style=''>occur</span> <span style=''>at</span> <span style=''>phone</span> <span style='background-color:rgba(0, 255, 0, 0.6521739130434783);'>boundaries</span> <span style='background-color:rgba(0, 255, 0, 0.431372549019608);'>Recurrent</span> <span style=''>data</span> <span style=''>input</span> <span style=''>also</span> <span style=''>helps</span> <span style=''>smooth</span> <span style=''>the</span> <span style=''>output</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>parameter</span> <span style=''>tracks</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Independent</span> <span style=''>testing</span> <span style=''>has</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>demonstrated</span> <span style=''>that</span> <span style=''>the</span> <span style=''>voice</span> <span style=''>quality</span> <span style=''>produced</span> <span style=''>by</span> <span style=''>this</span> <span style=''>system</span> <span style=''>compares</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>favorably</span> <span style=''>with</span> <span style=''>speech</span> <span style=''>from</span> <span style=''>existing</span> <span style='background-color:rgba(0, 255, 0, 0.4615384615384616);'>commercial</span> <span style=''>text</span> <span style=''>to</span> <span style=''>speech</span> <span style=''>systems</span> <br/><br/>

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(0, 255, 0, 0.3);'>Variational</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Inference</span> <span style=''>with</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Hamiltonian</span> <span style=''>Monte</span> <span style=''>Carlo</span> <br/><br/><span style='background-color:rgba(0, 255, 0, 0.3);'>Variational</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>inference</span> <span style=''>lies</span> <span style=''>at</span> <span style=''>the</span> <span style=''>core</span> <span style=''>of</span> <span style=''>many</span> <span style=''>state</span> <span style=''>of</span> <span style=''>the</span> <span style=''>art</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithms</span> <span style=''>To</span> <span style=''>improve</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>approximation</span> <span style=''>of</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>posterior</span> <span style=''>beyond</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>parametric</span> <span style=''>families</span> <span style=''>it</span> <span style=''>was</span> <span style=''>proposed</span> <span style=''>to</span> <span style=''>include</span> <span style=''>MCMC</span> <span style=''>steps</span> <span style=''>into</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>variational</span> <span style=''>lower</span> <span style=''>bound</span> <span style=''>In</span> <span style=''>this</span> <span style=''>work</span> <span style=''>we</span> <span style=''>explore</span> <span style=''>this</span> <span style=''>idea</span> <span style=''>using</span> <span style=''>steps</span> <span style=''>of</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Hamiltonian</span> <span style=''>Monte</span> <span style=''>Carlo</span> <span style=''>(HMC)</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithm</span> <span style=''>an</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>efficient</span> <span style=''>MCMC</span> <span style=''>method</span> <span style=''>In</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>particular</span> <span style=''>we</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>incorporate</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>acceptance</span> <span style=''>step</span> <span style=''>of</span> <span style=''>the</span> <span style=''>HMC</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithm</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>guaranteeing</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>asymptotic</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>convergence</span> <span style=''>to</span> <span style=''>the</span> <span style=''>true</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>posterior</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Additionally</span> <span style=''>we</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>introduce</span> <span style=''>some</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>extensions</span> <span style=''>to</span> <span style=''>the</span> <span style=''>HMC</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithm</span> <span style=''>geared</span> <span style=''>towards</span> <span style=''>faster</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>convergence</span> <span style=''>The</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>theoretical</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>advantages</span> <span style=''>of</span> <span style=''>these</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>modifications</span> <span style=''>are</span> <span style='background-color:rgba(0, 255,  ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Learning</span> <span style=''>Convex</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Inference</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Marginals</span> <br/><br/><span style='background-color:rgba(255, 0, 0, 0.3333333333333333);'>Graphical</span> <span style=''>models</span> <span style=''>trained</span> <span style=''>using</span> <span style=''>maximum</span> <span style='background-color:rgba(255, 0, 0, 0.44313725490196076);'>likelihood</span> <span style=''>are</span> <span style=''>a</span> <span style=''>common</span> <span style=''>tool</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>probabilistic</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>inference</span> <span style=''>of</span> <span style=''>marginal</span> <span style='background-color:rgba(255, 0, 0, 0.3141210374639769);'>distributions</span> <span style=''>However</span> <span style=''>this</span> <span style=''>approach</span> <span style=''>suffers</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>difficulties</span> <span style=''>when</span> <span style=''>either</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>inference</span> <span style=''>process</span> <span style=''>or</span> <span style=''>the</span> <span style=''>model</span> <span style=''>is</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>approximate</span> <span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>inference</span> <span style=''>process</span> <span style=''>is</span> <span style=''>first</span> <span style=''>defined</span> <span style=''>to</span> <span style=''>be</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>minimization</span> <span style=''>of</span> <span style=''>a</span> <span style=''>convex</span> <span style=''>function</span> <span style=''>inspired</span> <span style=''>by</span> <span style=''>free</span> <span style=''>energy</span> <span style='background-color:rgba(255, 0, 0, 0.456140350877193);'>approximations</span> <span style=''>Learning</span> <span style=''>is</span> <span style=''>then</span> <span style=''>done</span> <span style=''>directly</span> <span style=''>in</span> <span style=''>terms</span> <span style=''>of</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>performance</span> <span style=''>of</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>inference</span> <span style=''>process</span> <span style=''>at</span> <span style='background-color:rgba(255, 0, 0, 0.5862068965517241);'>univariate</span> <span style=''>marginal</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>prediction</span> <span style=''>The</span> <span style=''>main</span> <span style=''>novelty</span> <span style=''>is</span> <span style=''>that</span> <span style=''>this</span> <span style=''>is</span> <span style=''>a</span> <span style=''>direct</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>minimization</span> <span style=''>of</span> <span style=''>emperical</span> <span style=''>risk</span> <span style=''>where</span> <span style=''>the</span> <span style=''>risk</span> <span style=''>measures</span> <span style=''>the</span> <span style=''>accuracy</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>predicted</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>marginals</span> <br/><br/>

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Unifying</span> <span style=''>Decision</span> <span style=''>Trees</span> <span style=''>Split</span> <span style=''>Criteria</span> <span style=''>Using</span> <span style=''>Tsallis</span> <span style=''>Entropy</span> <br/><br/><span style=''>The</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>construction</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>efficient</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>effective</span> <span style=''>decision</span> <span style=''>trees</span> <span style=''>remains</span> <span style=''>a</span> <span style=''>key</span> <span style=''>topic</span> <span style=''>in</span> <span style=''>machine</span> <span style=''>learning</span> <span style=''>because</span> <span style=''>of</span> <span style=''>their</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>simplicity</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>flexibility</span> <span style=''>A</span> <span style=''>lot</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>heuristic</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithms</span> <span style=''>have</span> <span style=''>been</span> <span style=''>proposed</span> <span style=''>to</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>construct</span> <span style=''>near</span> <span style=''>optimal</span> <span style=''>decision</span> <span style=''>trees</span> <span style=''>ID3</span> <span style=''>C45</span> <span style=''>and</span> <span style=''>CART</span> <span style=''>are</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>classical</span> <span style=''>decision</span> <span style=''>tree</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithms</span> <span style=''>and</span> <span style=''>the</span> <span style=''>split</span> <span style=''>criteria</span> <span style=''>they</span> <span style=''>used</span> <span style=''>are</span> <span style=''>Shannon</span> <span style=''>entropy</span> <span style=''>Gain</span> <span style=''>Ratio</span> <span style=''>and</span> <span style=''>Gini</span> <span style=''>index</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>respectively</span> <span style=''>All</span> <span style=''>the</span> <span style=''>split</span> <span style=''>criteria</span> <span style=''>seem</span> <span style=''>to</span> <span style=''>be</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>independent</span> <span style=''>actually</span> <span style=''>they</span> <span style=''>can</span> <span style=''>be</span> <span style=''>unified</span> <span style=''>in</span> <span style=''>a</span> <span style=''>Tsallis</span> <span style=''>entropy</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>framework</span> <span style=''>Tsallis</span> <span style=''>entropy</span> <span style=''>is</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>generalization</span> <span style=''>of</span> <span style=''>Shannon</span> <span style=''>entropy</span> <span style=''>and</span> <span style=''>provides</span> <span style=''>a</span> <span style=''>new</span> <span style=''>approach</span> <span style=''>to</span> <span style=''>enhance</span> <span style=''>decision</span> <span style=''>trees</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>performance</span> <span style=''>with</span> <span style=''>an</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>adjustable</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>parameter</span> <span style=''>q</span> <span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>a</span> <span style=''>Tsallis</span> <span style=''>Entropy</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Criterion</span> <span style=''>(TEC)</span> <span  ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	experimental (0.13592579379236533)
# 	information (0.24937566892615054)
# 	knowledge (0.12343917231537638)
# 	processing (0.10916874777024617)
# 	segmentation (0.07349268640742063)
# 	representation (0.14056368176953266)
# 	different (0.25972172672136995)
# 	detection (0.12308241170174812)
# 	convolutional (0.13200142704245452)
# 	recognition (0.12986086336068497)
#
# Some Statistics words are:
# 	stochastic (0.1357035553329995)
# 	variables (0.13520280420630945)
# 	statistical (0.14872308462694042)
# 	estimation (0.17225838758137205)
# 	distribution (0.18027040560841262)
# 	theoretical (0.1512268402603906)
# 	algorithm (0.3870806209313971)
# 	inference (0.19228843264897347)
# 	dimensional (0.19078617926890334)
# 	regression (0.17626439659489235)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]), 
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="6b08e72c-65a2-4ae2-990f-cb9eab6bd1b9" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6b08e72c-65a2-4ae2-990f-cb9eab6bd1b9")) {                    Plotly.newPlot(                        "6b08e72c-65a2-4ae2-990f-cb9eab6bd1b9",                        [{"x":["integration","predictive","difficult","theoretically","performed","locations","distribution","generally","dimensions","computationally","especially","dimensional","nonparametric","posterior","accelerated","likelihood","inference","proposing","according","efficient","tractable","attractive","assignments","guaranteed","accelerate","mechanism","experimental","evaluates","evaluation","robustness","technique","combinations","efficiently","otherwise","potentially","developed","involving","principles","movements","horizontal","operating","performing","scenarios","functional","correction","components","introduces","generalization","construct","parameters","temperature","entailment","syntactic","modification","evolution","relations","different","languages","ferromagnetic","linguistic","simulations","interpretation","assumption","materials","interactions","interaction","naturally","operations","multiplication","randomized","scalability","activation","multiplications","conversely","asynchronous","associated","evaluations","sustainable","consequence","standpoint","algorithm","computational","significantly","increasing","sustainability","propagation","demonstrate","expensive","architectures","computation","drastically","containing","recognition","characterized","accounting","underlying","appearance","laplacian","relationships","regularization","overfitting","expressions","traditional","unordered","consistency","expression","conditional","restrictive","critically","discriminate","framework","activations","typically","intensity","databases","performance","described","challenging","experiments","automatically","structure","considerably","detection","automated","cognitive","improving","substantial","impairment","cognition","distinguish","minimizes","reinforcement","progression","approaches","prediction","supervised","participants","outperform","maximizes","differentiating","significant","conversational","conversation","probability","promising","transcripts","diagnosis","transcribed","simulation","alzheimers","specifically","observations","applications","residuals","covariate","heteroscedasticity","regression","dependent","synthetic","additional","derivative","covariance","frequently","heteroscedastic","unobserved","fundamental","population","conditions","following","algorithms","contemporary","estimated","prohibitively","computing","explicitly","sufficient","approximate","requirements","approximately","quadratic","furthermore","detecting","illustrate","alternative","execution","modularity","programming","drawbacks","conducted","advantages","impractical","difficulty","inherited","transition","definition","presenting","environments","generated","generation","conventional","describes","obstacles","benchmark","represent","independence","character","autonomous","preferred","resonance","segmentation","important","clustering","validating","resolution","authenticity","tomography","pathologies","enhancing","graphical","interface","neurological","segmented","increasingly","variations","diagnostic","interrogation","philosophy","reformulate","techniques","previously","recording","compressing","difficulties","induction","instantiating","necessary","methodological","exploiting","increased","reformulation","discovering","empirical","specialized","experienced","longstanding","including","systematic","reformulated","measurements","understanding","examining","discussed","potential","philosophical","immediate","applica ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	multiplications
# 	heteroscedasticity
# 	heteroscedastic
# 	prominence
# 	misspecification
# 	expecting
# 	lengthscales
# 	fragmentation
# 	regularisation
# 	heteroskedastic
# 	cytometry
# 	physiologic
# 	synchronously
# 	diverging
# 	popularized
# 	monetization
# 	homoscedastic
# 	submanifold
# 	submatrix
# 	katehakis
# Some words which never appear in Statistics papers:
# 	syntactic
# 	conversational
# 	transcribed
# 	inherited
# 	authenticity
# 	interrogation
# 	involvement
# 	partitionings
# 	equalization
# 	optoelectronic
# 	argumentation
# 	triangulation
# 	constancy
# 	localizing
# 	landmarks
# 	metaheuristics
# 	navigating
# 	occlusions
# 	registers
# 	propositional

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.0659798871719406e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7533333333333333
